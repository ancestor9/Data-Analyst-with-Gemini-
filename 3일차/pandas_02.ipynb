# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/Data-Analyst-with-Gemini-/blob/main/3%EC%9D%BC%EC%B0%A8/pandas_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python 프로그래밍 Pandas
# ## 데이터프레임 Dataframe

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# ## Pandas 란
# - 다른 Dataframe이나 고차원 객체로부터 컬럼을 추가 삭제
# - group by함수
# - 라벨 등을 이용한 데이터 부분 집합 추출
# - 데이터 세로 가로 합치기
# - 외부 데이터 연동의 견고함(CSV, Excel, databases, HDF5지원)
# - missing data(NaN) 처리

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
data = pd.read_csv('/content/한국도로교통공단_사고유형별 교통사고 통계_20231231.csv', encoding='euc-kr')
data.columns
# Out:
# Index(['사고유형대분류', '사고유형중분류', '사고유형', '사고건수', '사망자수', '중상자수', '경상자수', '부상신고자수'], dtype='object')

# %%
data.head()
# Out:
#   사고유형대분류     사고유형중분류        사고유형   사고건수  사망자수  중상자수  경상자수  부상신고자수
# 0    차대사람         횡단중         횡단중  13081   419  5868  6999     664
# 1    차대사람       차도통행중       차도통행중   4507   135  1704  2491     355
# 2    차대사람  길가장자리구역통행중  길가장자리구역통행중   1985    28   544  1303     190
# 3    차대사람       보도통행중       보도통행중   2632    24   849  1735     206
# 4    차대사람          기타          기타  14791   253  4778  9111    1466

# %% [markdown]
# ## loc, iloc - 두 개 이상의 연속된 컬럼 선택
# - loc은 Index가 가지고 있는 값을 기준으로 동작
# - iloc은 index의 위치 기준으로 동작합니다.(정수만 사용)

# %%
data.columns
data.iloc[:, [5,9]].head()
data.iloc[:, 5:9].head()
data.loc[:, '사망자수':'부상신고자수'].head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-9-3842628390.py in <cell line: 0>()
#       1 data.columns
# ----> 2 data.iloc[:, [5,9]].head()
#       3 data.iloc[:, 5:9].head()
#       4 data.loc[:, '사망자수':'부상신고자수'].head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1688
#    1689     def _getitem_tuple(self, tup: tuple):
# -> 1690         tup = self._validate_tuple_indexer(tup)
#    1691         with suppress(IndexingError):
#    1692             return self._getitem_lowerdim(tup)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _validate_tuple_indexer(self, key)
#     964         for i, k in enumerate(key):
#     965             try:
# --> 966                 self._validate_key(k, i)
#     967             except ValueError as err:
#     968                 raise ValueError(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1610             # check that the key does not exceed the maximum size of the index
#    1611             if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
# -> 1612                 raise IndexError("positional indexers are out-of-bounds")
#    1613         else:
#    1614             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# IndexError: positional indexers are out-of-bounds

# %% [markdown]
# ## 조건과 함께 컬럼 선택

# %%
data[data.사망자수 > 4].head()
# Out:
#   사고유형대분류     사고유형중분류        사고유형   사고건수  사망자수  중상자수  경상자수  부상신고자수
# 0    차대사람         횡단중         횡단중  13081   419  5868  6999     664
# 1    차대사람       차도통행중       차도통행중   4507   135  1704  2491     355
# 2    차대사람  길가장자리구역통행중  길가장자리구역통행중   1985    28   544  1303     190
# 3    차대사람       보도통행중       보도통행중   2632    24   849  1735     206
# 4    차대사람          기타          기타  14791   253  4778  9111    1466

# %%
data.loc[data.사상자수 > 4, '발생지시도']
# Out:
# 5        전남
# 8        경남
# 10       대구
# 19       전북
# 36       경남
#          ..
# 14491    강원
# 14554    대구
# 14591    경기
# 14620    전북
# 14621    경북
# Name: 발생지시도, Length: 610, dtype: object

# %%
data[data.사상자수 > 4].중상자수.head()
data[data.사상자수 > 4][['중상자수', '경상자수']].head()
# Out:
#              발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 발생지시도 사고유형_대분류  \
# 5   2012-07-15 8:00  주간  일     1     5     0     4       0    전남     차량단독
# 8   2012-10-01 2:00  야간  월     1     5     1     3       0    경남      차대차
# 10  2012-08-30 8:00  주간  목     1     5     1     3       0    대구      차대차
# 19  2012-01-01 1:00  야간  일     1     6     5     0       0    전북      차대차
# 36  2012-02-10 0:00  야간  금     1     5     3     1       0    경남      차대차
#
#    사고유형_중분류
# 5      전도전복
# 8    측면직각충돌
# 10       추돌
# 19     정면충돌
# 36       기타
# 5     0
# 8     1
# 10    1
# 19    5
# 36    3
# Name: 중상자수, dtype: int64
# 5     0
# 8     1
# 10    1
# 19    5
# 36    3
# Name: 중상자수, dtype: int64
#     중상자수  경상자수
# 5      0     4
# 8      1     3
# 10     1     3
# 19     5     0
# 36     3     1

# %% [markdown]
# # <font color='red'>데이터 selct - 조건, very useful </font>

# %% [markdown]
# ## 부상신고자가 3이상인 사고인지 여부(Boolean)를 list로 만들기

# %%
hurts=[]

for hurt in data.부상신고자수 :
    if hurt >= 3 :
        hurts.append(True)
    if hurt < 3 :
        hurts.append(False)

len(hurts)
True in hurts, False in hurts
hurts[:10]
# Out:
# 14624
# (True, True)
# [False, False, False, False, False, False, False, False, False, False]

# %% [markdown]
# ## Boolean 값이 참인 것만 가져오기

# %%
lots_of_hurts = pd.Series(hurts)
data[lots_of_hurts].head(3)
# Out:
#                발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 발생지시도 사고유형_대분류  \
# 203  2012-09-04 16:00  주간  화     1     8     0     3       4    전북      차대차
# 209   2012-11-03 2:00  야간  토     1    22     6    12       3    경북      차대차
# 340   2012-12-11 5:00  야간  화     1     7     0     0       6    경기      차대차
#
#     사고유형_중분류
# 203       기타
# 209       추돌
# 340       추돌

# %% [markdown]
# ## list comprehension 활용

# %%
lots_of_hurts2 = [ hurt >= 3 for hurt in data.부상신고자수]
data[lots_of_hurts2].head(3)
# Out:
#                발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 발생지시도 사고유형_대분류  \
# 203  2012-09-04 16:00  주간  화     1     8     0     3       4    전북      차대차
# 209   2012-11-03 2:00  야간  토     1    22     6    12       3    경북      차대차
# 340   2012-12-11 5:00  야간  화     1     7     0     0       6    경기      차대차
#
#     사고유형_중분류
# 203       기타
# 209       추돌
# 340       추돌

# %%
lots_of_hurts3 = data.부상신고자수 >= 3
data[lots_of_hurts3].head(3)
# Out:
#                발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 발생지시도 사고유형_대분류  \
# 203  2012-09-04 16:00  주간  화     1     8     0     3       4    전북      차대차
# 209   2012-11-03 2:00  야간  토     1    22     6    12       3    경북      차대차
# 340   2012-12-11 5:00  야간  화     1     7     0     0       6    경기      차대차
#
#     사고유형_중분류
# 203       기타
# 209       추돌
# 340       추돌

# %% [markdown]
# ## 단순 조건문

# %%
data[data.부상신고자수 >= 3]['사상자수']
data.loc[data.부상신고자수 >= 3, '사상자수']
# Out:
# 203        8
# 209       22
# 340        7
# 589        7
# 774       10
# 883       25
# 1571     100
# 2233       6
# 2237      20
# 2364       7
# 2670       6
# 2998      10
# 3751      12
# 4275      25
# 5523       9
# 6602      13
# 8441      47
# 8729      34
# 10258      7
# 10595     22
# 10919     20
# 11850      8
# 12646     18
# 13204     19
# 13207      6
# 13216      4
# 13514      5
# 13837     15
# 14440      6
# 14591     10
# Name: 사상자수, dtype: int64
# 203        8
# 209       22
# 340        7
# 589        7
# 774       10
# 883       25
# 1571     100
# 2233       6
# 2237      20
# 2364       7
# 2670       6
# 2998      10
# 3751      12
# 4275      25
# 5523       9
# 6602      13
# 8441      47
# 8729      34
# 10258      7
# 10595     22
# 10919     20
# 11850      8
# 12646     18
# 13204     19
# 13207      6
# 13216      4
# 13514      5
# 13837     15
# 14440      6
# 14591     10
# Name: 사상자수, dtype: int64

# %% [markdown]
# ## 복합 조건문

# %%
data[(data.부상신고자수 >= 8) & (data.사상자수 >= 4)]
# Out:
#                  발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 발생지시도 사고유형_대분류  \
# 1571   2012-02-24 15:00  주간  금     4   100     6    23      67    강원      차대차
# 4275   2013-09-12 19:00  야간  목     2    25     3     4      16    경기      차대차
# 6602   2013-10-23 16:00  주간  수     1    13     3     0       9    경기      차대차
# 8729   2014-12-31 19:00  야간  수     1    34     3     0      30    경기      차대차
# 10919   2014-11-04 7:00  주간  화     3    20     3     0      14    제주      차대차
#
#       사고유형_중분류
# 1571        추돌
# 4275        추돌
# 6602        기타
# 8729        기타
# 10919     정면충돌

# %%
(data.부상신고자수 >= 8) | (data.사상자수 >= 30)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14619    False
# 14620    False
# 14621    False
# 14622    False
# 14623    False
# Length: 14624, dtype: bool

# %%
data[(data.부상신고자수 >= 8) | (data.사상자수 >= 30)]
# Out:
#                  발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 발생지시도 사고유형_대분류  \
# 407    2012-10-17 21:00  야간  수     3    35    26     6       0    대구      차대차
# 742    2012-05-10 10:00  주간  목     1    37     7    29       0    제주      차대차
# 1571   2012-02-24 15:00  주간  금     4   100     6    23      67    강원      차대차
# 2290    2013-12-18 6:00  주간  수     4    36    25     7       0    강원      차대차
# 3341   2013-03-31 20:00  야간  일     1    57    45    10       1    전북      차대차
# 4159   2013-11-10 11:00  주간  일     1    43    14    28       0    충남      차대차
# 4275   2013-09-12 19:00  야간  목     2    25     3     4      16    경기      차대차
# 6602   2013-10-23 16:00  주간  수     1    13     3     0       9    경기      차대차
# 8441    2013-09-05 9:00  주간  목     1    47    28    11       7    인천      차대차
# 8729   2014-12-31 19:00  야간  수     1    34     3     0      30    경기      차대차
# 10473  2012-10-30 13:00  주간  화     1    40     6    33       0    강원      차대차
# 10919   2014-11-04 7:00  주간  화     3    20     3     0      14    제주      차대차
#
#       사고유형_중분류
# 407     측면직각충돌
# 742     측면직각충돌
# 1571        추돌
# 2290        추돌
# 3341        기타
# 4159        추돌
# 4275        추돌
# 6602        기타
# 8441        추돌
# 8729        기타
# 10473     정면충돌
# 10919     정면충돌

# %%
data[(data.부상신고자수 == 8) | (data.부상신고자수 == 9)]
# Out:
#                 발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 발생지시도 사고유형_대분류  \
# 6602  2013-10-23 16:00  주간  수     1    13     3     0       9    경기      차대차
#
#      사고유형_중분류
# 6602       기타

# %% [markdown]
# ## 복합 조건문 isin 사용

# %%
data.rename(columns = {'부상신고자수' : '부상자수'}, inplace = True)

# %%
data[data.부상자수.isin([8,9])]
# Out:
#                 발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도 사고유형_대분류  \
# 6602  2013-10-23 16:00  주간  수     1    13     3     0     9    경기      차대차
#
#      사고유형_중분류
# 6602       기타

# %% [markdown]
# ## 값에 특정 문자가 포함되어 있는지 조건으로 활용

# %%
data.columns
# Out:
# Index(['발생년월일시', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상자수', '발생지시도',
#        '사고유형_대분류', '사고유형_중분류'],
#       dtype='object')

# %%
data.columns.str.replace('사고유형_', '')
data.columns = data.columns.str.replace('사고유형_', '')
# Out:
# Index(['발생년월일시', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상자수', '발생지시도',
#        '대분류', '중분류'],
#       dtype='object')

# %%
data.중분류.str.contains('충돌').head()
data[data.중분류.str.contains('충돌')].head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: 중분류, dtype: bool
#               발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도   대분류     중분류
# 2   2012-10-26 20:00  야간  금     1     2     1     0     0    경북   차대차  측면직각충돌
# 7   2012-09-17 14:00  주간  월     1     1     0     0     0    충남  차량단독   공작물충돌
# 8    2012-10-01 2:00  야간  월     1     5     1     3     0    경남   차대차  측면직각충돌
# 16   2012-11-06 1:00  야간  화     1     1     0     0     0    경남  차량단독   공작물충돌
# 19   2012-01-01 1:00  야간  일     1     6     5     0     0    전북   차대차    정면충돌

# %% [markdown]
# ## 데이터 Select - loc, iloc

# %%
data.loc[0, :]
data.loc[[0,1,2], :]
data.loc[0:3, :]
data.loc[:, ['발생지시도', '대분류']]
# Out:
# 발생년월일시    2012-05-09 1:00
# 주야                     야간
# 요일                      수
# 사망자수                    1
# 사상자수                    1
# 중상자수                    0
# 경상자수                    0
# 부상자수                    0
# 발생지시도                  경남
# 대분류                   차대차
# 중분류                    추돌
# Name: 0, dtype: object
#              발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도  대분류     중분류
# 0   2012-05-09 1:00  야간  수     1     1     0     0     0    경남  차대차      추돌
# 1  2012-03-30 13:00  주간  금     1     1     0     0     0    경기  차대차      추돌
# 2  2012-10-26 20:00  야간  금     1     2     1     0     0    경북  차대차  측면직각충돌
#              발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도  대분류     중분류
# 0   2012-05-09 1:00  야간  수     1     1     0     0     0    경남  차대차      추돌
# 1  2012-03-30 13:00  주간  금     1     1     0     0     0    경기  차대차      추돌
# 2  2012-10-26 20:00  야간  금     1     2     1     0     0    경북  차대차  측면직각충돌
# 3  2012-06-28 14:00  주간  목     1     1     0     0     0    경기  차대차      추돌
#       발생지시도   대분류
# 0        경남   차대차
# 1        경기   차대차
# 2        경북   차대차
# 3        경기   차대차
# 4        전남   차대차
# ...     ...   ...
# 14619    경북  차대사람
# 14620    전북   차대차
# 14621    경북   차대차
# 14622    경남   차대차
# 14623    경남  차량단독
#
# [14624 rows x 2 columns]

# %%
data
# Out:
#                  발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도   대분류  \
# 0       2012-05-09 1:00  야간  수     1     1     0     0     0    경남   차대차
# 1      2012-03-30 13:00  주간  금     1     1     0     0     0    경기   차대차
# 2      2012-10-26 20:00  야간  금     1     2     1     0     0    경북   차대차
# 3      2012-06-28 14:00  주간  목     1     1     0     0     0    경기   차대차
# 4       2012-06-18 4:00  야간  월     1     1     0     0     0    전남   차대차
# ...                 ...  .. ..   ...   ...   ...   ...   ...   ...   ...
# 14619  2014-07-05 16:00  주간  토     1     1     0     0     0    경북  차대사람
# 14620  2014-07-12 18:00  야간  토     1     8     2     5     0    전북   차대차
# 14621   2014-07-15 4:00  야간  화     2     6     2     2     0    경북   차대차
# 14622  2014-07-10 20:00  야간  목     1     3     0     2     0    경남   차대차
# 14623  2014-07-20 10:00  주간  일     1     1     0     0     0    경남  차량단독
#
#           중분류
# 0          추돌
# 1          추돌
# 2      측면직각충돌
# 3          추돌
# 4          추돌
# ...       ...
# 14619      기타
# 14620  측면직각충돌
# 14621      기타
# 14622      추돌
# 14623    전도전복
#
# [14624 rows x 11 columns]

# %%
data.head(2)
# Out:
#              발생년월일시 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도 사고유형_대분류 사고유형_중분류
# 0   2012-05-09 1:00  수     1     1     0     0     0    경남      차대차       추돌
# 1  2012-03-30 13:00  금     1     1     0     0     0    경기      차대차       추돌

# %%
del data['주야']

# %%
data.drop(['주야', '요일'], axis=1)
# Out:
#                  발생년월일시  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도 사고유형_대분류 사고유형_중분류
# 0       2012-05-09 1:00     1     1     0     0     0    경남      차대차       추돌
# 1      2012-03-30 13:00     1     1     0     0     0    경기      차대차       추돌
# 2      2012-10-26 20:00     1     2     1     0     0    경북      차대차   측면직각충돌
# 3      2012-06-28 14:00     1     1     0     0     0    경기      차대차       추돌
# 4       2012-06-18 4:00     1     1     0     0     0    전남      차대차       추돌
# ...                 ...   ...   ...   ...   ...   ...   ...      ...      ...
# 14619  2014-07-05 16:00     1     1     0     0     0    경북     차대사람       기타
# 14620  2014-07-12 18:00     1     8     2     5     0    전북      차대차   측면직각충돌
# 14621   2014-07-15 4:00     2     6     2     2     0    경북      차대차       기타
# 14622  2014-07-10 20:00     1     3     0     2     0    경남      차대차       추돌
# 14623  2014-07-20 10:00     1     1     0     0     0    경남     차량단독     전도전복
#
# [14624 rows x 9 columns]

# %%
data.drop(['주야', '발생년월일시', '대분류'], axis=1).head()
# Out:
#              발생년월일시 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도  대분류     중분류
# 0   2012-05-09 1:00  수     1     1     0     0     0    경남  차대차      추돌
# 1  2012-03-30 13:00  금     1     1     0     0     0    경기  차대차      추돌
# 2  2012-10-26 20:00  금     1     2     1     0     0    경북  차대차  측면직각충돌
# 3  2012-06-28 14:00  목     1     1     0     0     0    경기  차대차      추돌
# 4   2012-06-18 4:00  월     1     1     0     0     0    전남  차대차      추돌
#   요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도     중분류
# 0  수     1     1     0     0     0    경남      추돌
# 1  금     1     1     0     0     0    경기      추돌
# 2  금     1     2     1     0     0    경북  측면직각충돌
# 3  목     1     1     0     0     0    경기      추돌
# 4  월     1     1     0     0     0    전남      추돌

# %%
from faker import Faker
fake = Faker('ko_KR')

# %%
import warnings
warnings.filterwarnings('ignore')
data['가상주소'] = [fake.address() for i in range(len(data))]

# %%
data
# Out:
#                  발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도   대분류  \
# 0       2012-05-09 1:00  야간  수     1     1     0     0     0    경남   차대차
# 1      2012-03-30 13:00  주간  금     1     1     0     0     0    경기   차대차
# 2      2012-10-26 20:00  야간  금     1     2     1     0     0    경북   차대차
# 3      2012-06-28 14:00  주간  목     1     1     0     0     0    경기   차대차
# 4       2012-06-18 4:00  야간  월     1     1     0     0     0    전남   차대차
# ...                 ...  .. ..   ...   ...   ...   ...   ...   ...   ...
# 14619  2014-07-05 16:00  주간  토     1     1     0     0     0    경북  차대사람
# 14620  2014-07-12 18:00  야간  토     1     8     2     5     0    전북   차대차
# 14621   2014-07-15 4:00  야간  화     2     6     2     2     0    경북   차대차
# 14622  2014-07-10 20:00  야간  목     1     3     0     2     0    경남   차대차
# 14623  2014-07-20 10:00  주간  일     1     1     0     0     0    경남  차량단독
#
#           중분류                        가상주소
# 0          추돌  충청북도 천안시 서북구 개포40로 (예원김마을)
# 1          추돌                 경기도 안양시 역삼길
# 2      측면직각충돌               인천광역시 송파구 역삼가
# 3          추돌      강원도 단양군 봉은사52거리 (하은박면)
# 4          추돌       서울특별시 구로구 개포길 (진호김마을)
# ...       ...                         ...
# 14619      기타         강원도 금산군 봉은사로 (경자이면)
# 14620  측면직각충돌              대전광역시 중구 서초중앙가
# 14621      기타               인천광역시 도봉구 잠실길
# 14622      추돌               전라남도 양평군 영동대길
# 14623    전도전복         경상북도 천안시 동남구 석촌호수0길
#
# [14624 rows x 12 columns]

# %%
data[data.사망자수 >= 5].가상주소
data.loc[data.사망자수 >= 5, '가상주소']
# Out:
# 137      경상북도 성남시 수정구 논현937길 (상훈양김리)
# 151            강원도 광명시 개포88가 (수진김심동)
# 3741          대전광역시 강서구 논현5길 (영숙심마을)
# 3975           충청북도 의정부시 테헤란로 (혜진이리)
# 6740                충청북도 양주시 서초중앙7거리
# 7908                  전라북도 양평군 테헤란거리
# 11717          강원도 광주시 서초대1길 (광수송김면)
# 14290              울산광역시 성북구 삼성028거리
# Name: 가상주소, dtype: object
# 137      경상북도 성남시 수정구 논현937길 (상훈양김리)
# 151            강원도 광명시 개포88가 (수진김심동)
# 3741          대전광역시 강서구 논현5길 (영숙심마을)
# 3975           충청북도 의정부시 테헤란로 (혜진이리)
# 6740                충청북도 양주시 서초중앙7거리
# 7908                  전라북도 양평군 테헤란거리
# 11717          강원도 광주시 서초대1길 (광수송김면)
# 14290              울산광역시 성북구 삼성028거리
# Name: 가상주소, dtype: object

# %% [markdown]
# ## iloc => numpy array slicing과 유사

# %%
data.iloc[:, 0:4].head()
data.iloc[0:3, :]
data[0:3]
# Out:
#              발생년월일시  주야 요일  사망자수
# 0   2012-05-09 1:00  야간  수     1
# 1  2012-03-30 13:00  주간  금     1
# 2  2012-10-26 20:00  야간  금     1
# 3  2012-06-28 14:00  주간  목     1
# 4   2012-06-18 4:00  야간  월     1
#              발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도  대분류     중분류  \
# 0   2012-05-09 1:00  야간  수     1     1     0     0     0    경남  차대차      추돌
# 1  2012-03-30 13:00  주간  금     1     1     0     0     0    경기  차대차      추돌
# 2  2012-10-26 20:00  야간  금     1     2     1     0     0    경북  차대차  측면직각충돌
#
#                          가상주소
# 0  충청북도 천안시 서북구 개포40로 (예원김마을)
# 1                 경기도 안양시 역삼길
# 2               인천광역시 송파구 역삼가
#              발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도  대분류     중분류  \
# 0   2012-05-09 1:00  야간  수     1     1     0     0     0    경남  차대차      추돌
# 1  2012-03-30 13:00  주간  금     1     1     0     0     0    경기  차대차      추돌
# 2  2012-10-26 20:00  야간  금     1     2     1     0     0    경북  차대차  측면직각충돌
#
#                          가상주소
# 0  충청북도 천안시 서북구 개포40로 (예원김마을)
# 1                 경기도 안양시 역삼길
# 2               인천광역시 송파구 역삼가

# %% [markdown]
# ## 조건에 맞는 행의 index를 list로

# %%
data.index
data.index[data.사망자수 >= 5].tolist()
select_row = data.index[data.사망자수 >= 5].tolist()
data.loc[select_row]
# Out:
# RangeIndex(start=0, stop=14624, step=1)
# [137, 151, 3741, 3975, 6740, 7908, 11717, 14290]
#                  발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지시도  대분류   중분류  \
# 137     2012-11-24 4:00  야간  토     5     6     1     0     0    경기  차대차    추돌
# 151     2012-07-05 9:00  주간  목     5    10     3     2     0    경기  차대차    추돌
# 3741   2013-12-14 13:00  주간  토     6    10     4     0     0    울산  차대차    추돌
# 3975    2012-12-19 1:00  야간  수     5     5     0     0     0    강원  차대차  정면충돌
# 6740   2013-11-09 18:00  야간  토     5     7     1     1     0    전남  차대차    기타
# 7908   2013-11-27 17:00  주간  수     6    24     0    18     0    충남  차대차    기타
# 11717   2014-11-30 0:00  야간  일     5     5     0     0     0    경기  차대차    추돌
# 14290   2014-10-28 8:00  주간  화     5     5     0     0     0    전북  차대차    추돌
#
#                               가상주소
# 137    경상북도 성남시 수정구 논현937길 (상훈양김리)
# 151          강원도 광명시 개포88가 (수진김심동)
# 3741        대전광역시 강서구 논현5길 (영숙심마을)
# 3975         충청북도 의정부시 테헤란로 (혜진이리)
# 6740              충청북도 양주시 서초중앙7거리
# 7908                전라북도 양평군 테헤란거리
# 11717        강원도 광주시 서초대1길 (광수송김면)
# 14290            울산광역시 성북구 삼성028거리

# %% [markdown]
# # End
