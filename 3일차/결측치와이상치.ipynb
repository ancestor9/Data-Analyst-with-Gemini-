# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/Data-Analyst-with-Gemini-/blob/main/3%EC%9D%BC%EC%B0%A8/%EA%B2%B0%EC%B8%A1%EC%B9%98%EC%99%80%EC%9D%B4%EC%83%81%EC%B9%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 1. 결측값(Missing value)
# # 2. 결측값 대체(Missing value Imputation)

# %% [markdown]
# ## 2.1. 제거법

# %%
# @title
import pandas as pd
import numpy as np

# 예제 데이터프레임 생성
data = {'A': [1, 2, np.nan, 4, 5],
        'B': [5, np.nan, np.nan, 8, 10]}
df = pd.DataFrame(data)
df
# Out:
#      A     B
# 0  1.0   5.0
# 1  2.0   NaN
# 2  NaN   NaN
# 3  4.0   8.0
# 4  5.0  10.0

# %%
# @title
df.dropna()
# Out:
#      A     B
# 0  1.0   5.0
# 3  4.0   8.0
# 4  5.0  10.0

# %% [markdown]
# ## 2.2. 평균대치법

# %%
# @title
# 결측값을 평균값으로 대체
df['A'].fillna(df['A'].mean(), inplace=True)
df['B'].fillna(df['B'].mean(), inplace=True)
df
# Out:
#      A          B
# 0  1.0   5.000000
# 1  2.0   7.666667
# 2  3.0   7.666667
# 3  4.0   8.000000
# 4  5.0  10.000000

# %% [markdown]
# ## 2.3. 단순확률 대치법

# %%
# @title
data = {'A': [1, 2, np.nan, 4, 5],
        'B': [5, np.nan, np.nan, 8, 10]}
df = pd.DataFrame(data)

# 결측값을 단순확률로 대체하는 함수 정의
def random_imputation(series):
    missing = series.isnull()
    num_missing = missing.sum()
    if num_missing == 0:
        return series
    imputed_values = series[~missing].sample(num_missing, replace=True).values
    series[missing] = imputed_values
    return series

# 결측값 대체
df['A'] = random_imputation(df['A'])
df['B'] = random_imputation(df['B'])

df
# Out:
#      A     B
# 0  1.0   5.0
# 1  2.0   5.0
# 2  5.0  10.0
# 3  4.0   8.0
# 4  5.0  10.0

# %% [markdown]
# ### 2.3.1. Hot-deck 대체법
# Hot-deck 대체법은 결측치를 가진 관측값을 비슷한 다른 관측값으로 대체하는 방법입니다. 여기서는 같은 열의 랜덤한 비결측값을 사용합니다.

# %%
# @title
data = {'A': [1, 2, np.nan, 4, 5],
        'B': [5, np.nan, np.nan, 8, 10]}
df = pd.DataFrame(data)
df

# Hot-deck 대체 함수
def hot_deck_imputation(series):
    missing = series.isnull()
    num_missing = missing.sum()
    if num_missing == 0:
        return series
    imputed_values = series[~missing].sample(num_missing, replace=True).values
    series[missing] = imputed_values
    return series

# 결측값 대체
df['A'] = hot_deck_imputation(df['A'])
df['B'] = hot_deck_imputation(df['B'])
df
# Out:
#      A     B
# 0  1.0   5.0
# 1  2.0   NaN
# 2  NaN   NaN
# 3  4.0   8.0
# 4  5.0  10.0
#      A     B
# 0  1.0   5.0
# 1  2.0   5.0
# 2  5.0   8.0
# 3  4.0   8.0
# 4  5.0  10.0

# %% [markdown]
# ### 2.3.2. Nearest Neighbor 대체법
# Nearest Neighbor 대체법은 결측치를 가진 관측값과 가장 가까운 비결측값을 가진 관측값으로 대체하는 방법입니다. 여기서는 KNNImputer를 사용합니다.

# %%
# @title
# 예제 데이터프레임 생성
data = {'A': [1, 2, np.nan, 4, 5],
        'B': [5, np.nan, np.nan, 8, 10]}
df = pd.DataFrame(data)
df
# Out:
#      A     B
# 0  1.0   5.0
# 1  2.0   NaN
# 2  NaN   NaN
# 3  4.0   8.0
# 4  5.0  10.0

# %%
# @title
from sklearn.impute import KNNImputer
# KNNImputer를 사용하여 결측값 대체
imputer = KNNImputer(n_neighbors=2)  # 이웃의 개수는 상황에 맞게 설정
imputed_df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

imputed_df
# Out:
#      A          B
# 0  1.0   5.000000
# 1  2.0   6.500000
# 2  3.0   7.666667
# 3  4.0   8.000000
# 4  5.0  10.000000

# %%
# @title
(2+4)/2
(5+8)/2
# Out:
# 3.0
# 6.5

# %% [markdown]
# ## 2.4. 다중 대치법

# %%
# @title
# 예제 데이터프레임 생성
data = {'A': [1, 2, np.nan, 4, 5],
        'B': [5, np.nan, np.nan, 8, 10]}
df = pd.DataFrame(data)
df
# Out:
#      A     B
# 0  1.0   5.0
# 1  2.0   NaN
# 2  NaN   NaN
# 3  4.0   8.0
# 4  5.0  10.0

# %%
# @title
from statsmodels.imputation.mice import MICEData
# MICE로 다중 대치 수행
mice_data = MICEData(df)
mice_data.update_all()

# 다중 대치된 데이터프레임 얻기
imputed_df = mice_data.data

imputed_df
# Out:
#      A     B
# 0  1.0   5.0
# 1  2.0   8.0
# 2  4.0   8.0
# 3  5.0  10.0

# %% [markdown]
# # 3. 이상값(Outliers)

# %%
# @title
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# 예제 데이터 생성
np.random.seed(0)
data = np.random.normal(50, 10, 1000)  # 평균 50, 표준편차 10인 정규분포 데이터 100개 생성
data = np.append(data, [120, 130, 140])  # 이상치 추가

# 데이터프레임으로 변환
df = pd.DataFrame(data, columns=['Value'])
df
# Out:
#            Value
# 0      67.640523
# 1      54.001572
# 2      59.787380
# 3      72.408932
# 4      68.675580
# ...          ...
# 998    38.523891
# 999    46.418859
# 1000  120.000000
# 1001  130.000000
# 1002  140.000000
#
# [1003 rows x 1 columns]

# %% [markdown]
# ## 3.1. ESD 방법을 이용한 이상치 탐지 및 시각화

# %%
# @title
def esd_test(data, alpha=0.05):
    n = len(data)
    outliers = []
    for i in range(n):
        mean = np.mean(data)
        std_dev = np.std(data, ddof=1)
        max_dev = max(abs(data - mean))
        test_statistic = max_dev / std_dev
        critical_value = stats.t.ppf(1 - alpha / (2 * (n - i)), n - i - 2)
        if test_statistic > critical_value:
            outliers.append(data[np.argmax(abs(data - mean))])
            data = np.delete(data, np.argmax(abs(data - mean)))
        else:
            break
    return outliers

# ESD를 사용하여 이상치 탐지
outliers_esd = esd_test(df['Value'].values)

# 시각화
plt.figure(figsize=(12, 6))
plt.hist(df['Value'], bins=20, color='blue', alpha=0.7, label='Data')
plt.scatter(outliers_esd, np.zeros_like(outliers_esd), color='red', zorder=5, label='Outliers (ESD)', marker='x', s=100)
plt.axvline(np.mean(df['Value']), color='green', linestyle='dashed', linewidth=1, label='Mean')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('ESD Outlier Detection on Normally Distributed Data')
plt.legend()
plt.show()
# Out:
# (array([  9.,  22.,  77., 172., 234., 228., 150.,  70.,  31.,   7.,   0.,
#           0.,   0.,   0.,   0.,   0.,   1.,   0.,   1.,   1.]),
#  array([ 19.53856945,  25.56164098,  31.58471251,  37.60778403,
#          43.63085556,  49.65392709,  55.67699862,  61.70007014,
#          67.72314167,  73.7462132 ,  79.76928473,  85.79235625,
#          91.81542778,  97.83849931, 103.86157084, 109.88464236,
#         115.90771389, 121.93078542, 127.95385695, 133.97692847,
#         140.        ]),
#  <BarContainer object of 20 artists>)
# Text(0.5, 0, 'Value')
# Text(0, 0.5, 'Frequency')
# Text(0.5, 1.0, 'ESD Outlier Detection on Normally Distributed Data')

# %% [markdown]
# ## 3.2. 사분위수 상자그림을 이용한 이상치 탐지

# %%
# @title
# 사분위수 계산
Q1 = df['Value'].quantile(0.25)
Q3 = df['Value'].quantile(0.75)
IQR = Q3 - Q1

# 이상치 범위 설정
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# 이상치 탐지
outliers_iqr = df[(df['Value'] < lower_bound) | (df['Value'] > upper_bound)]['Value']

# 시각화
plt.figure(figsize=(10, 5))
plt.boxplot(df['Value'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c3b2321c510>,
#   <matplotlib.lines.Line2D at 0x7c3b2321d090>],
#  'caps': [<matplotlib.lines.Line2D at 0x7c3b2321db10>,
#   <matplotlib.lines.Line2D at 0x7c3b2321e4d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7c3b23213c90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c3b23210490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c3b2321f650>],
#  'means': []}

# %% [markdown]
# ## **이상치 확인방법(정규뷴포도와 상자그림)**
#
# <img src = 'https://miro.medium.com/v2/resize:fit:1400/0*jBnB0iboGyU5EzVy.png'>
#
# # <font color ='red'> **Check points**
# <img src='https://blog.kakaocdn.net/dn/cRWMP9/btrS6SA5x3l/0p57ymgL9Rj9EcR2kTjlD0/img.png'>
